# %% [markdown]
# # To explore Business Analytics

# %% [markdown]
# # ----- M.Manyu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\kumar\Downloads\SampleSuperstore.csv')
dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
dataset.isnull().any()
# Out:
# Ship Mode       False
# Segment         False
# Country         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
import seaborn as sns
sns.boxplot(x=dataset['Sales'])

# %%
sns.boxplot(x=dataset['Discount'])

# %%
sns.boxplot(x=dataset['Profit'])

# %%
sales=dataset['Sales'].sum()
sales
# Out:
# 2297200.8603

# %%
profit=dataset['Profit'].sum()
profit
# Out:
# 286397.0217

# %%
diff=profit-sales
diff
# Out:
# -2010803.8386

# %%
dataset.drop_duplicates(keep='first',inplace=True)

# %%
dataset
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sales=dataset['Sales'].sum()
sales
# Out:
# 2296195.5903

# %%
profit=dataset['Profit'].sum()
profit
# Out:
# 286241.4226

# %%
diff=profit-sales
diff
# Out:
# -2009954.1676999999

# %%
sns.relplot(x='Sales',y='Profit',hue='Category',data=dataset)

# %%
sns.relplot(x='Discount',y='Profit',hue='Category',data=dataset)

# %%
sns.relplot(x='Discount',y='Sales',hue='Category',data=dataset)

# %%
state_sales=dataset.groupby('State').Sales.sum()

# %%
state_sales=state_sales.sort_values(ascending=False)

# %%
state_sales
# Out:
# State
# California              457576.2715
# New York                310827.1510
# Texas                   170124.5418
# Washington              138560.8100
# Pennsylvania            116496.3620
# Florida                  89473.7080
# Illinois                 80162.5370
# Ohio                     77976.7640
# Michigan                 75879.6440
# Virginia                 70636.7200
# North Carolina           55603.1640
# Indiana                  53555.3600
# Georgia                  49095.8400
# Kentucky                 36591.7500
# New Jersey               35764.3120
# Arizona                  35282.0010
# Wisconsin                32114.6100
# Colorado                 32108.1180
# Tennessee                30661.8730
# Minnesota                29863.1500
# Massachusetts            28634.4340
# Delaware                 27451.0690
# Maryland                 23705.5230
# Rhode Island             22627.9560
# Missouri                 22205.1500
# Oklahoma                 19683.3900
# ...

# %%
state_profit=dataset.groupby('State').Profit.sum()

# %%
state_profit=state_profit.sort_values(ascending=False)

# %%
state_profit
# Out:
# State
# California              76330.7891
# New York                74015.4622
# Washington              33368.2375
# Michigan                24428.0903
# Virginia                18597.9504
# Indiana                 18382.9363
# Georgia                 16250.0433
# Kentucky                11199.6966
# Minnesota               10823.1874
# Delaware                 9977.3748
# New Jersey               9772.9138
# Wisconsin                8401.8004
# Rhode Island             7285.6293
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Missouri                 6436.2105
# Alabama                  5786.8253
# Oklahoma                 4853.9560
# Arkansas                 4008.6871
# Connecticut              3511.4918
# Nevada                   3316.7659
# Mississippi              3172.9762
# Utah                     2546.5335
# Vermont                  2244.9783
# Louisiana                2196.1023
# Nebraska                 2037.0942
# ...

# %%
plt.plot(state_sales,state_profit)
plt.show()

# %%
state_sales.plot(kind='bar')
plt.show()

# %%
state_profit.plot(kind='bar')
plt.show()

# %%
dataset.plot(kind='scatter',x='Sales',y='Profit',c='Discount',colormap='viridis')
plt.show()

# %%
compare=dataset.loc[:,['Sales','Quantity','Discount','Profit']]
sns.pairplot(compare)

# %%
correlation=compare.corr()
sns.heatmap(correlation,annot=True)

# %%
#when discount is zero
data=dataset[dataset['Discount']==0]
sns.relplot(x='Sales',y='Profit',data=data)

# %%
correlation=data.corr()
sns.heatmap(correlation,annot=True)

# %%
sns.relplot(x='Sales',y='Profit',hue='Category',data=data)

# %%
sns.boxplot(x='Category',y='Profit',data=data)

# %%
#whwn discount is not zero
data1=dataset[dataset['Discount']!=0]
sns.relplot(x='Sales',y='Profit',hue='Discount',data=data1)

# %%
sns.relplot(x='Sales',y='Profit',hue='Category',data=data1)

# %%
correlation=data1.corr()
sns.heatmap(correlation,annot=True)
